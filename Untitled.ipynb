# %%
pip install pyautogui
# Out:
# ...
#      ---------------------------------------- 0.0/61.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.2 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.2 kB 217.9 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.2 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 61.2/61.2 kB 271.3 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
pip install dropbox
# Out:
# ...
#   Obtaining dependency information for dropbox from https://files.pythonhosted.org/packages/86/96/1cd39be567d8e361fc06a4135e40ddbf1410f99524771a7f3e5807a26a35/dropbox-11.36.2-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/162.3 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/162.3 kB ? eta -:--:--
#      ------- ----------------------------- 30.7/162.3 kB 435.7 kB/s eta 0:00:01
#      ------------------ ------------------ 81.9/162.3 kB 573.4 kB/s eta 0:00:01
#      --------------------------- -------- 122.9/162.3 kB 654.9 kB/s eta 0:00:01
#      ---------------------------------- - 153.6/162.3 kB 612.6 kB/s eta 0:00:01
#      ------------------------------------ 162.3/162.3 kB 571.5 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/594.0 kB ? eta -:--:--
#    ------- -------------------------------- 112.6/594.0 kB 3.3 MB/s eta 0:00:01
# ...

# %%
import pyautogui
import datetime
import dropbox
import os
import time

ACCESS_TOKEN = 'sl.BvYbTynUhn_J7GulSjn2WegIuULxwzDgJbYV_4CAvKbnrbPlgenvohy7xImc4SAzbfR-xSY4kS3zGlTgjeO7gvzxZvgrBDd8_sUH7vOAbA9D_zfnSiCh6Su8p2XaGfc-x21AQpYvt4TwoRNVD3pl'

def take_screenshot():
    now = datetime.datetime.now()
    timestamp = now.strftime("%Y-%m-%d_%H_%M-%S")
    screenshot_file= f"screenshot_{timestamp}.png"
    screenshot = pyautogui.screenshot()
    screenshot.save(screenshot_file)
    return screenshot_file

def upload_to_dropbox(file_path):
    dbx = dropbox.Dropbox(ACCESS_TOKEN)
    
    with open(file_path, 'rb') as f:
        dbx.files_upload(f.read(), f"/{file_path}")
    print("Файл загружен")

while(True):
    screenshot_file = take_screenshot()
        
    upload_to_dropbox(screenshot_file)

    os.remove(screenshot_file)
    time.sleep(5)
# Out:
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# Файл загружен
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 27
#      24 while(True):
#      25     screenshot_file = take_screenshot()
# ---> 27     upload_to_dropbox(screenshot_file)
#      29     os.remove(screenshot_file)
#      30     time.sleep(5)
#
# Cell In[16], line 21, in upload_to_dropbox(file_path)
#      18 dbx = dropbox.Dropbox(ACCESS_TOKEN)
#      20 with open(file_path, 'rb') as f:
# ---> 21     dbx.files_upload(f.read(), f"/{file_path}")
#      22 print("Файл загружен")
#
# ...
